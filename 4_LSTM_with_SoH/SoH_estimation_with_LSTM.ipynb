# %% [markdown]
# ## 0.Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import os
import glob
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import math

import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input, SimpleRNN, Dropout
#from keras.models import Sequential
#from keras.layers import Dense, LSTM, SimpleRNN, Dropout
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import model_from_json
from keras import optimizers

# %% [markdown]
# ## 1. Load Dataset

# %%
dir = 'refined_dataset'
listdir = os.listdir(dir)

print(listdir)
print("The number of dataset :", len(listdir))

# %%
num = ['B05', 'B07', 'B18', 'B33', 'B34', 'B46', 'B47', 'B48']
for i in range(len(listdir)):
    vector = np.zeros((1,3))
    path = os.path.join(os.getcwd(), 'refined_dataset/', num[i] + '_discharge_soh.csv')
    csv = pd.read_csv(path)
    df = pd.DataFrame(csv)
    
    vec = df[['cycle', 'capacity', 'SOH']]
    
    globals()['data_{}'.format(num[i])] = vec

# %%
data = pd.read_csv('refined_dataset/B05_discharge_soh.csv')
df = pd.DataFrame(data)
df

# %%
data_B05  ## result

# %%
for i in range(len(listdir)):
    print("Shape of data :", np.shape(globals()['data_{}'.format(num[i])]))

# %%
print(listdir)
dataset = data_B48["SOH"]
cycle = data_B48['cycle']

dataset = np.array(dataset)
dataset = dataset.reshape((len(dataset),1))
dataset.shape

# %% [markdown]
# ## 2. Split train and test dataset

# %%
train_size = int(len(dataset) * 0.5)
# train_size = int(len(dataset) * 0.5)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

print(trainX.shape)
print(testX.shape)

# %% [markdown]
# ## 3. Training with LSTM

# %%
model = Sequential()
#model.add(LSTM(64, input_shape=(trainX.shape[1], trainX.shape[2])))

#model.add(Dense(1))
model = Sequential([
    Input(shape=(10, 1)),  # Definir la forma aquí
    LSTM(50, activation='relu'),
    Dense(1)
])
model.compile(loss='mae', optimizer='adam')

# %%
history = model.fit(trainX, trainY, epochs=100, batch_size=20, validation_data=(testX, testY), verbose=1, shuffle = False)
# Out:
# Epoch 1/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3216 - val_loss: 0.0084
# Epoch 2/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0084 - val_loss: 0.0082
# Epoch 3/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0080
# Epoch 4/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0080
# Epoch 5/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0080
# Epoch 6/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0100 - val_loss: 0.0080
# Epoch 7/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0079
# Epoch 8/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0080
# Epoch 9/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0079
# Epoch 10/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0099 - val_loss: 0.0081
# Epoch 11/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0086 - val_loss: 0.0081
# Epoch 12/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0080
# Epoch 13/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0079
# Epoch 14/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0099 - val_loss: 0.0079
# Epoch 15/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0090 - val_loss: 0.0078
# Epoch 16/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0102 - val_loss: 0.0078
# Epoch 17/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0100 - val_loss: 0.0081
# Epoch 18/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0092 - val_loss: 0.0079
# Epoch 19/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0099 - val_loss: 0.0079
# Epoch 20/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0091 - val_loss: 0.0077
# Epoch 21/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0099 - val_loss: 0.0076
# Epoch 22/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0096 - val_loss: 0.0076
# Epoch 23/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 24/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083 - val_loss: 0.0076
# Epoch 25/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0076
# Epoch 26/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0086 - val_loss: 0.0076
# Epoch 27/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0075
# Epoch 28/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0092 - val_loss: 0.0077
# Epoch 29/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0085 - val_loss: 0.0075
# Epoch 30/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0078
# Epoch 31/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 32/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0088 - val_loss: 0.0078
# Epoch 33/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 34/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0082 - val_loss: 0.0075
# Epoch 35/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0087 - val_loss: 0.0074
# Epoch 36/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0090 - val_loss: 0.0074
# Epoch 37/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0087 - val_loss: 0.0078
# Epoch 38/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0090 - val_loss: 0.0076
# Epoch 39/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 40/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - val_loss: 0.0074
# Epoch 41/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0095 - val_loss: 0.0075
# Epoch 42/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0091 - val_loss: 0.0075
# Epoch 43/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 44/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 45/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0085 - val_loss: 0.0073
# Epoch 46/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0091 - val_loss: 0.0074
# Epoch 47/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 48/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 49/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0087 - val_loss: 0.0074
# Epoch 50/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0083 - val_loss: 0.0076
# Epoch 51/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0087 - val_loss: 0.0075
# Epoch 52/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0087 - val_loss: 0.0073
# Epoch 53/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0085 - val_loss: 0.0071
# Epoch 54/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0092 - val_loss: 0.0074
# Epoch 55/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0075 - val_loss: 0.0073
# Epoch 56/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 57/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0071
# Epoch 58/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0085 - val_loss: 0.0071
# Epoch 59/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081 - val_loss: 0.0071
# Epoch 60/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0074 - val_loss: 0.0070
# Epoch 61/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081 - val_loss: 0.0070
# Epoch 62/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0088 - val_loss: 0.0071
# Epoch 63/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0079 - val_loss: 0.0071
# Epoch 64/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0079 - val_loss: 0.0070
# Epoch 65/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 66/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0084 - val_loss: 0.0071
# Epoch 67/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0087 - val_loss: 0.0073
# Epoch 68/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0082 - val_loss: 0.0070
# Epoch 69/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 70/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0079 - val_loss: 0.0071
# Epoch 71/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 72/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0080 - val_loss: 0.0070
# Epoch 73/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0075 - val_loss: 0.0070
# Epoch 74/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0078 - val_loss: 0.0068
# Epoch 75/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 76/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0080 - val_loss: 0.0068
# Epoch 77/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081 - val_loss: 0.0069
# Epoch 78/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0072 - val_loss: 0.0067
# Epoch 79/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083 - val_loss: 0.0068
# Epoch 80/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077 - val_loss: 0.0067
# Epoch 81/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0086 - val_loss: 0.0067
# Epoch 82/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0076 - val_loss: 0.0067
# Epoch 83/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 84/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0074 - val_loss: 0.0067
# Epoch 85/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0077 - val_loss: 0.0067
# Epoch 86/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0079 - val_loss: 0.0067
# Epoch 87/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0076 - val_loss: 0.0066
# Epoch 88/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0066
# Epoch 89/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0076 - val_loss: 0.0068
# Epoch 90/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 91/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0069 - val_loss: 0.0066
# Epoch 92/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0078 - val_loss: 0.0066
# Epoch 93/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0072 - val_loss: 0.0066
# Epoch 94/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0081 - val_loss: 0.0066
# Epoch 95/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0072 - val_loss: 0.0066
# Epoch 96/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0070 - val_loss: 0.0066
# Epoch 97/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 98/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0086 - val_loss: 0.0067
# Epoch 99/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0069 - val_loss: 0.0065
# Epoch 100/100
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - val_loss: 0.0067

# %%
# save model architecture
model_json = model.to_json()
open('50%/model/B48_model.json', 'w').write(model_json)

# save model's learned weights
model.save_weights('50%/model/B48.weights.h5', overwrite=True)

# %%
# Load trained model
from keras.models import model_from_json 

json_file = open("50%/model/B48_model.json", "r")
loaded_model_json = json_file.read() 
json_file.close()
loaded_model = model_from_json(loaded_model_json)
 
# model weight load 
loaded_model.load_weights("50%/model/B48_weights.h5")
print("Loaded model from disk")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 10
#       7 loaded_model = model_from_json(loaded_model_json)
#       9 # model weight load
# ---> 10 loaded_model.load_weights("50%/model/B48_weights.h5")
#      11 print("Loaded model from disk")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\legacy\saving\legacy_h5_format.py:440, in _set_weights(instance, symbolic_weights, weight_values, name, skip_mismatch)
#     430             warnings.warn(
#     431                 f"Skipping loading weights for {name}"
#     432                 f"due to mismatch in shape for "
#    (...)
#     437                 stacklevel=2,
#     438             )
#     439             continue
# --> 440         raise ValueError(
#     441             f"Shape mismatch in {name}"
#     442             f"for weight {symbolic_weights[i].path}. "
#     443             f"Weight expects shape {expected_shape}. "
#     444             "Received saved weight "
#     445             f"with shape {received_shape}"
#     446         )
#     447     symbolic_weights[i].assign(weight_value)
#     449 if hasattr(instance, "finalize_state") and symbolic_weights:
#
# ValueError: Shape mismatch in layer #0 (named lstm_2)for weight lstm_2/lstm_cell/kernel. Weight expects shape (1, 200). Received saved weight with shape (1, 256)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.axis([-5, 100, 0, 0.07])
plt.legend() 
plt.show()

# %%
yhat = model.predict(testX)
tyhat = model.predict(trainX)
plt.plot(yhat, label='Prediction')
plt.plot(testY, label='Real data')
plt.legend()
plt.show()
# Out:
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step

# %%
print("Shape of train data :", trainX.shape)
print("Shape of prediction :", yhat.shape)
print("Shape of real data :", testY.shape)
# Out:
# Shape of train data : (11738, 1, 1)
# Shape of prediction : (11738, 1)
# Shape of real data : (11738,)

# %%
rmse = math.sqrt(mean_squared_error(testY, yhat))
mae = mean_absolute_error(testY, yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAE: %.3f' % mae)
# Out:
# Test RMSE: 0.008
# Test MAE: 0.007

# %% [markdown]
# ## 4. Visualization

# %%
print("Shape of cycle :", np.shape(cycle))

cycle1 = cycle[0:train_size-1]
cycle2 = cycle[train_size+1:len(dataset)]

# cycle1 = cycle[0:train_size]
# cycle2 = cycle[train_size:len(dataset)]

print(np.shape(cycle1), np.shape(cycle2))
# Out:
# Shape of cycle : (23478,)
# (11738,) (11738,)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

plt.plot(cycle1, trainX[:,0],label='Used real data', linewidth = 3, color='r')
plt.plot(cycle2, testY,label='Real data', linewidth = 3, color='b')
# plt.plot(cycle2, yhat[:,0],label='LSTM Prediction', linewidth = 3, color='g')
plt.plot(cycle2, yhat[:,0],label='LSTM Prediction', linewidth = 3, color='g')
plt.legend(prop={'size': 16})

plt.ylabel('SoH', fontsize = 15)
plt.xlabel('Discharge cycle', fontsize = 15)
plt.title(str(num[7]) + " SOH Prediction", fontsize = 15)
plt.savefig('50%/fig/' + str(num[7]) + '_LSTM.jpg')
plt.show()
